# %% [markdown]
# # [Travelbrag](http://travelbrag.ca)
# Andrea & Brett's travelogue.

# %%
import datetime
import pandas

cities = pandas.read_csv("cities.csv")
travelogue = pandas.read_csv("travelogue.csv", parse_dates=["arrived", "departed"])
today = datetime.date.today()
colours = {frozenset(["Andrea", "Brett"]): "#00FA21", frozenset(["Andrea"]): "#F2FA00",
           frozenset(["Brett"]): "#005CFA"}

# %% [markdown]
# # What was our last vacation?
# A _vacation_ is classified as the last time Andrea and I travelled for non-work purposes together.

# %%
both_of_us = travelogue[travelogue["travellers"] == "Andrea & Brett"]
vacations = both_of_us[~both_of_us["work"]]
last_vacation = vacations.sort_values(by="departed").tail(1).iloc[0]
departed = last_vacation["departed"].date()

print("Our last vacation was to {}, {} for {} on {}.".format(last_vacation["city"],
                                                             last_vacation["country"],
                                                             last_vacation["purpose"],
                                                             departed.isoformat()))
# Out:
# Our last vacation was to Pender Island, CAN for Pender Island on 2022-05-26.

# %% [markdown]
# # Where have we been in the last 12 months?

# %%
import datetime

year_ago = pandas.Timestamp(today - datetime.timedelta(days=365))
travelogue[travelogue["arrived"] >= year_ago].sort_values(by="arrived")
# Out:
#            purpose    arrived   departed      travellers           city  \
# 265  Pender Island 2022-05-22 2022-05-26  Andrea & Brett  Pender Island
#
#     country   work comment
# 265     CAN  False     NaN

# %% [markdown]
# # Where have we visited?

# %%
full_country_names = {
    "CAN": "Canada",
    "USA": "America",
    "GBR": "Great Britain",
    "JPN": "Japan",
    "BEL": "Belgium",
    "CZE": "Czech Republic",
    "ESP": "Spain",
    "FRA": "France",
    "CHE": "Switzerland",
    "CUB": "Cuba",
    "ARG": "Argentina",
    "DOM": "Dominican Republic",
    "ISL": "Iceland",
    "NLD": "Netherlands",
    "IND": "India",
    "NZL": "New Zealand",
    "IRL": "Ireland",
    "THA": "Thailand"
}

locations = travelogue[['city', 'country']].drop_duplicates()
countries = locations['country'].drop_duplicates().tolist()
city_names = tuple((row[0], row[1]) for row in locations.values.tolist())

print("(In chronological order of first visit)")
print()
print(len(cities), "cities across", len(countries), "countries:")
for country in countries:
    print("   ", full_country_names[country])
    for city, _ in filter(lambda x: x[1] == country, city_names):
        print("       ", city)
# Out:
# (In chronological order of first visit)
#
# 150 cities across 18 countries:
#     America
#         Yosemite Valley
#         Las Vegas
#         Anaheim
#         Chicago
#         Washington, D.C.
#         Mammoth Lakes
#         Montclair
#         New York
#         Atlantic City
#         Addison
#         Rosemont
#         Seattle
#         Pittsburgh
#         Charlottesville
#         Langley
#         Meridian
#         Roseville
#         Atlanta
#         Raleigh
#         San Francisco
#         Mountain View
#         Monterey
#         Portland
#         Santa Clara
#         Ann Arbor
#         Redmond
#         Austin
#         Union City
#         New Haven
#         Boise
#         Palo Alto
#         Los Angeles
#         Cleveland
#         Everett
#     Great Britain
#         London
#         Brighton
#         York
#         Edinburgh
#         Oxford
#         Ely
#         Shoreham-by-Sea
#         Manchester
#         Liverpool
#         Birmingham
#         Lancaster
#         Glasgow
#         Stirling
#         Bugbrooke
#     Japan
#         Annaka
#         Hiroshima
#         Kyoto
#         Nara
#         Osaka
#         Takasaki
#         Tokyo
#     Canada
#         Sackville
#         Summerside
#         Yarmouth
#         Annapolis Royal
#         Amherst
#         Digby
#         Kentville
#         Moncton
#         Shediac
#         Calgary
#         Edmonton
#         Victoria
#         Vancouver
#         Bowen Island
#         Toronto
#         Niagara Falls
#         Kingston
#         Ottawa
#         Montréal
#         Québec
#         Fredericton
#         Halifax
#         Charlottetown
#         Manning Park
#         Osoyoos
#         Kelowna
#         Monck Park
#         St. John's
#         Guelph
#         Sudbury
#         Wawa
#         Thunder Bay
#         Winnipeg
#         Regina
#         Creston
#         Nelson
#         Tofino
#         Ucluelet
#         Quispamsis
#         Saint John
#         St. Martins
#         Wolfville
#         Lunenburg
#         Peggy’s Cove
#         Truro
#         Hopewell Rocks Park
#         Merritt
#         Lake Cowichan
#         Port Renfrew
#         Parksville
#         Harrison Mills
#         Galiano Island
#         Pender Island
#     Belgium
#         Brussels
#         Ghent
#     Cuba
#         Havana
#     Czech Republic
#         Prague
#     Spain
#         Barcelona
#     France
#         Grenoble
#         Paris
#     Switzerland
#         Geneva
#     Argentina
#         Buenos Aires
#     Dominican Republic
#         Punta Cana
#     Iceland
#         Reykjavik
#     Netherlands
#         Amsterdam
#     India
#         Delhi
#         Agra
#         Fatehpur Sikri
#         Jaipur
#         Pune
#     New Zealand
#         Auckland
#         Devonport
#         Hahei
#         Matamata
#         Rotorua
#         Taupo
#         Wellington
#         Kaikoura
#         Hanmer Springs
#         Hokitika
#         Franz Josef
#         Queenstown
#         Doubtful Sound
#         Hooker Valley
#         Twizel
#         Lake Tekapo
#         Christchurch
#         Waiheke Island
#     Ireland
#         Dublin
#         Tralee
#         Galway
#     Thailand
#         Bangkok
#         Kanchanaburi
#         Ayutthaya
#         Chiang Mai

# %% [markdown]
# # Is the data valid?
# Manually entering data into a spreadsheet is always error-prone, so some quick checks are always useful to catch common mistakes.

# %%
import datetime
import re
import urllib.parse

# CITIES
# Latitude
if any(lat < -90 or lat > 90 for lat in cities['latitude']):
    raise ValueError('malformed latitude')
    
# Longitude
if any(lng < -180 or lng > 180 for lng in cities['longitude']):
    raise ValueError('malformed longitude')

# TRAVELOGUE
# Travellers
if any(x not in {"Andrea", "Brett", "Andrea & Brett"} for x in travelogue['travellers']):
    raise ValueError('unrecognized travellers')
    
# City
if any(pandas.isnull(travelogue['city'])):
    raise ValueError('missing the city in the travelogue data')
elif not all(travelogue["city"].isin(cities["city"].values)):
    raise ValueError("city in travelogue but not in cities")

# Country
if any(len(x) != 3 or x.upper() != x for x in travelogue['country']):
    bad_countries = []
    raise ValueError('malformed country')
elif not all(travelogue["country"].isin(cities["country"].values)):
    raise ValueError("country in travelogue but not in cities")
elif len(pandas.merge(travelogue, cities, on=["city", "country"])) != len(travelogue):
    raise ValueError("city/country in travelogue not in cities data")
    
# Arrived/Departed
if any(x.arrived > x.departed for x in travelogue.itertuples()):
    raise ValueError("arrival date passed departure date")
        
print('All travelogue data is valid!')
# Out:
# All travelogue data is valid!

# %% [markdown]
# # GeoJSON map output
# A GeoJSON file is generated to allow for easy mapping of visited cities.

# %%
import json

def split_travellers(travellers):
    return travellers.split(" & ")

complete_travelogue = pandas.merge(travelogue, cities, on=["city", "country"])
geo_data = {}
for trip in complete_travelogue.itertuples():
    location = trip.city, trip.country
    if location not in geo_data:
        data = {"coordinates": [trip.longitude, trip.latitude],
                "travellers": set(split_travellers(trip.travellers)), "last visit": trip.departed,
                "work": bool(trip.work)}
        geo_data[location] = data
    else:
        data = geo_data[location]
        data["travellers"].update(split_travellers(trip.travellers))
        if data["last visit"] < trip.departed:
            data["last visit"] = trip.departed
geojson = {"type": "FeatureCollection", "features": []}
for location, data in geo_data.items():
    point = {"type": "Feature", "geometry": {"type": "Point", "coordinates": data["coordinates"]},
             "properties": {"city": ", ".join(location), "last visit": data["last visit"].strftime("%Y-%m-%d"),
                            "marker-color": colours[frozenset(data["travellers"])], "work": data["work"]}}
    geojson["features"].append(point)
with open("travelogue.geojson", "w", encoding="utf-8") as file:
    json.dump(geojson, file, sort_keys=True)

# %%
import folium

world_map = folium.Map(location=[0, 0], zoom_start=3)
folium.GeoJson(geojson, name="Trips").add_to(world_map)
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e2e884ee6df1cfd57fe090abc5e8de30 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e2e884ee6df1cfd57fe090abc5e8de30&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e2e884ee6df1cfd57fe090abc5e8de30 = L.map(
#                 &quot;map_e2e884ee6df1cfd57fe090abc5e8de30&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9ceb402ce66f4e31074e1d4a171abe0f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e2e884ee6df1cfd57fe090abc5e8de30);
#
#
#
#         function geo_json_9d314c4760b08fca47afa0f58f4e8d3f_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_9d314c4760b08fca47afa0f58f4e8d3f = L.geoJson(null, {
#                 onEachFeature: geo_json_9d314c4760b08fca47afa0f58f4e8d3f_onEachFeature,
#
#         });
#
#         function geo_json_9d314c4760b08fca47afa0f58f4e8d3f_add (data) {
#             geo_json_9d314c4760b08fca47afa0f58f4e8d3f
#                 .addData(data)
#                 .addTo(map_e2e884ee6df1cfd57fe090abc5e8de30);
#         }
#             geo_json_9d314c4760b08fca47afa0f58f4e8d3f_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [-119.578, 37.741], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;city&quot;: &quot;Yosemite Valley, USA&quot;, &quot;last visit&quot;: &quot;2003-07-01&quot;, &quot;marker-color&quot;: &quot;#005CFA&quot;, &quot;work&quot;: false}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-0.126, 51.509], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;city&quot;: &quot;London, GBR&quot;, &quot;last visit&quot;: &quot;2019-09-14&quot;, &quot;marker-color&quot;: &quot;#00FA21&quot;, &quot;work&quot;: false}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-0.139, 50.828], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;city&quot;: &quot;Brighton, GBR&quot;, &quot;last visit&quot;: &quot;2006-07-01&quot;, &quot;marker-color&quot;: &quot;#00FA21&quot;, &quot;work&quot;: false}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-1.083, 53.958], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;city&quot;: &quot;York, GBR&quot;, &quot;last visit&quot;: &quot;2002-01-01&quot;, &quot;marker-color&quot;: &quot;#005CFA&quot;, &quot;work&quot;: false}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-3.196, 55.952], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;city&quot;: &quot;Edinburgh, GBR&quot;, &quot;last visit&quot;: &quot;2010-07-31&quot;, &quot;marker-color&quot;: &quot;#00FA21&quot;, &quot;work&quot;: false}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-1.256, 51.752], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;city&quot;: &quot;Oxford, GBR&quot;, &quot;last visit&quot;: &quot;2002-01-01&quot;, &quot;marker-color&quot;: &quot;#005CFA&quot;, &quot;work&quot;: false}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-115.137, 36.175], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;city&quot;: &quot;Las Vegas, USA&quot;, &quot;last visit&quot;: &quot;2009-08-01&quot;, &quot;marker-color&quot;: &quot;#00FA21&quot;, &quot;work&quot;: false}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [138.9, 36.31667], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;city&quot;: &quot;Annaka, JPN&quot;, &quot;last visit&quot;: &quot;2008-01-01&quot;, &quot;marker-color&quot;: &quot;#F2FA00&quot;, &quot;work&quot;: false}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [132.45937, 35.02107], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;city&quot;: &quot;Hiroshima, JPN&quot;, &quot;last visit&quot;: &quot;2008-01-01&quot;, &quot;marker-color&quot;: &quot;#F2FA00&quot;, &quot;work&quot;: false}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [135.75385, 35.02107], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;city&quot;: &quot;Kyoto, JPN&quot;, &quot;last visit&quot;: &quot;2008-01-01&quot;, &quot;marker-color&quot;: &quot;#F2FA00&quot;, &quot;work&quot;: false}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [135.80485, 34.68505], &quot;type&q
