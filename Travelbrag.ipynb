# %% [markdown]
# # [Travelbrag](http://travelbrag.ca)
# Andrea & Brett's travelogue.

# %%
import datetime
import pandas

cities = pandas.read_csv("cities.csv")
travelogue = pandas.read_csv("travelogue.csv", parse_dates=["arrived", "departed"])
today = datetime.date.today()
colours = {frozenset(["Andrea", "Brett"]): "#00FA21", frozenset(["Andrea"]): "#F2FA00",
           frozenset(["Brett"]): "#005CFA"}

# %% [markdown]
# # What was our last vacation?
# A _vacation_ is classified as the last time Andrea and I travelled for non-work purposes together.

# %%
both_of_us = travelogue[travelogue["travellers"] == "Andrea & Brett"]
vacations = both_of_us[~both_of_us["work"]]
last_vacation = vacations.sort_values(by="departed").tail(1).iloc[0]
departed = last_vacation["departed"].date()

print("Our last vacation was to {}, {} for {} on {}.".format(last_vacation["city"],
                                                             last_vacation["country"],
                                                             last_vacation["purpose"],
                                                             departed.isoformat()))
# Out:
# Our last vacation was to Galiano Island, CAN for Thanksgiving on 2021-10-13.

# %% [markdown]
# # Where have we been in the last 12 months?

# %%
year_ago = pandas.Timestamp(today - datetime.timedelta(days=365))
travelogue[travelogue["arrived"] >= year_ago].sort_values(by="arrived")
# Out:
#            purpose    arrived   departed      travellers            city  \
# 261  Fraser Valley 2021-07-05 2021-07-09  Andrea & Brett  Harrison Mills
# 262     Labour Day 2021-09-03 2021-09-07  Andrea & Brett          Tofino
# 263   Thanksgiving 2021-10-06 2021-10-13  Andrea & Brett  Galiano Island
#
#     country   work comment
# 261     CAN  False     NaN
# 262     CAN  False     NaN
# 263     CAN  False     NaN

# %% [markdown]
# # Where have we visited?

# %%
full_country_names = {
    "CAN": "Canada",
    "USA": "America",
    "GBR": "Great Britain",
    "JPN": "Japan",
    "BEL": "Belgium",
    "CZE": "Czech Republic",
    "ESP": "Spain",
    "FRA": "France",
    "CHE": "Switzerland",
    "CUB": "Cuba",
    "ARG": "Argentina",
    "DOM": "Dominican Republic",
    "ISL": "Iceland",
    "NLD": "Netherlands",
    "IND": "India",
    "NZL": "New Zealand",
    "IRL": "Ireland",
    "THA": "Thailand"
}

locations = travelogue[['city', 'country']].drop_duplicates()
countries = locations['country'].drop_duplicates().tolist()
city_names = tuple((row[0], row[1]) for row in locations.values.tolist())

print("(In chronological order of first visit)")
print()
print(len(cities), "cities across", len(countries), "countries:")
for country in countries:
    print("   ", full_country_names[country])
    for city, _ in filter(lambda x: x[1] == country, city_names):
        print("       ", city)
# Out:
# (In chronological order of first visit)
#
# 149 cities across 18 countries:
#     America
#         Yosemite Valley
#         Las Vegas
#         Anaheim
#         Chicago
#         Washington, D.C.
#         Mammoth Lakes
#         Montclair
#         New York
#         Atlantic City
#         Addison
#         Rosemont
#         Seattle
#         Pittsburgh
#         Charlottesville
#         Langley
#         Meridian
#         Roseville
#         Atlanta
#         Raleigh
#         San Francisco
#         Mountain View
#         Monterey
#         Portland
#         Santa Clara
#         Ann Arbor
#         Redmond
#         Austin
#         Union City
#         New Haven
#         Boise
#         Palo Alto
#         Los Angeles
#         Cleveland
#         Everett
#     Great Britain
#         London
#         Brighton
#         York
#         Edinburgh
#         Oxford
#         Ely
#         Shoreham-by-Sea
#         Manchester
#         Liverpool
#         Birmingham
#         Lancaster
#         Glasgow
#         Stirling
#         Bugbrooke
#     Japan
#         Annaka
#         Hiroshima
#         Kyoto
#         Nara
#         Osaka
#         Takasaki
#         Tokyo
#     Canada
#         Sackville
#         Summerside
#         Yarmouth
#         Annapolis Royal
#         Amherst
#         Digby
#         Kentville
#         Moncton
#         Shediac
#         Calgary
#         Edmonton
#         Victoria
#         Vancouver
#         Bowen Island
#         Toronto
#         Niagara Falls
#         Kingston
#         Ottawa
#         Montréal
#         Québec
#         Fredericton
#         Halifax
#         Charlottetown
#         Manning Park
#         Osoyoos
#         Kelowna
#         Monck Park
#         St. John's
#         Guelph
#         Sudbury
#         Wawa
#         Thunder Bay
#         Winnipeg
#         Regina
#         Creston
#         Nelson
#         Tofino
#         Ucluelet
#         Quispamsis
#         Saint John
#         St. Martins
#         Wolfville
#         Lunenburg
#         Peggy’s Cove
#         Truro
#         Hopewell Rocks Park
#         Merritt
#         Lake Cowichan
#         Port Renfrew
#         Parksville
#         Harrison Mills
#         Galiano Island
#     Belgium
#         Brussels
#         Ghent
#     Cuba
#         Havana
#     Czech Republic
#         Prague
#     Spain
#         Barcelona
#     France
#         Grenoble
#         Paris
#     Switzerland
#         Geneva
#     Argentina
#         Buenos Aires
#     Dominican Republic
#         Punta Cana
#     Iceland
#         Reykjavik
#     Netherlands
#         Amsterdam
#     India
#         Delhi
#         Agra
#         Fatehpur Sikri
#         Jaipur
#         Pune
#     New Zealand
#         Auckland
#         Devonport
#         Hahei
#         Matamata
#         Rotorua
#         Taupo
#         Wellington
#         Kaikoura
#         Hanmer Springs
#         Hokitika
#         Franz Josef
#         Queenstown
#         Doubtful Sound
#         Hooker Valley
#         Twizel
#         Lake Tekapo
#         Christchurch
#         Waiheke Island
#     Ireland
#         Dublin
#         Tralee
#         Galway
#     Thailand
#         Bangkok
#         Kanchanaburi
#         Ayutthaya
#         Chiang Mai

# %% [markdown]
# # Is the data valid?
# Manually entering data into a spreadsheet is always error-prone, so some quick checks are always useful to catch common mistakes.

# %%
import datetime

# CITIES
# Latitude
if any(lat < -90 or lat > 90 for lat in cities['latitude']):
    raise ValueError('malformed latitude')
    
# Longitude
if any(lng < -180 or lng > 180 for lng in cities['longitude']):
    raise ValueError('malformed longitude')

# TRAVELOGUE
# Travellers
if any(x not in {"Andrea", "Brett", "Andrea & Brett"} for x in travelogue['travellers']):
    raise ValueError('unrecognized travellers')
    
# City
if any(pandas.isnull(travelogue['city'])):
    raise ValueError('missing the city in the travelogue data')
elif not all(travelogue["city"].isin(cities["city"].values)):
    raise ValueError("city in travelogue but not in cities")

# Country
if any(len(x) != 3 or x.upper() != x for x in travelogue['country']):
    bad_countries = []
    raise ValueError('malformed country')
elif not all(travelogue["country"].isin(cities["country"].values)):
    raise ValueError("country in travelogue but not in cities")
elif len(pandas.merge(travelogue, cities, on=["city", "country"])) != len(travelogue):
    raise ValueError("city/country in travelogue not in cities data")
    
# Arrived/Departed
if any(x.arrived > x.departed for x in travelogue.itertuples()):
    raise ValueError("arrival date passed departure date")
        
print('All travelogue data is valid!')
# Out:
# All travelogue data is valid!

# %% [markdown]
# # GeoJSON map output
# A GeoJSON file is generated to allow for easy mapping of visited cities.

# %%
import json

def split_travellers(travellers):
    return travellers.split(" & ")

complete_travelogue = pandas.merge(travelogue, cities, on=["city", "country"])
geo_data = {}
for trip in complete_travelogue.itertuples():
    location = trip.city, trip.country
    if location not in geo_data:
        data = {"coordinates": [trip.longitude, trip.latitude],
                "travellers": set(split_travellers(trip.travellers)), "last visit": trip.departed,
                "work": bool(trip.work)}
        geo_data[location] = data
    else:
        data = geo_data[location]
        data["travellers"].update(split_travellers(trip.travellers))
        if data["last visit"] < trip.departed:
            data["last visit"] = trip.departed
geojson = {"type": "FeatureCollection", "features": []}
for location, data in geo_data.items():
    point = {"type": "Feature", "geometry": {"type": "Point", "coordinates": data["coordinates"]},
             "properties": {"city": ", ".join(location), "last visit": data["last visit"].strftime("%Y-%m-%d"),
                            "marker-color": colours[frozenset(data["travellers"])], "work": data["work"]}}
    geojson["features"].append(point)
with open("travelogue.geojson", "w", encoding="utf-8") as file:
    json.dump(geojson, file, sort_keys=True)

# %%
import folium

world_map = folium.Map(location=[0, 0], zoom_start=3)
folium.GeoJson(geojson, name="Trips").add_to(world_map)
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_1fa6485072c34b809fb63c37b9c11f0e%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_1fa6485072c34b809fb63c37b9c11f0e%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_1fa6485072c34b809fb63c37b9c11f0e%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_1fa6485072c34b809fb63c37b9c11f0e%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B0.0%2C%200.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs% ...
